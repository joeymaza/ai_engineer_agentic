# %% [markdown]
# ## Week 2 Day 2
#
# Our first Agentic Framework project!!
#
# Prepare yourself for something ridiculously easy.
#
# We're going to build a simple Agent system for generating cold sales outreach emails:
# 1. Agent workflow
# 2. Use of tools to call functions
# 3. Agent collaboration via Tools and Handoffs

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">IMPORTANT PLEASE READ - Emails with SendGrid</h2>
#             <span style="color:#ff7800;">We are going to use the email provider SendGrid. But this is OPTIONAL.<br/>
#             The next cell contains instructions for SendGrid. But if this gives you problems, or if you'd rather use any alternative,<br/>
#             please see <a href="https://edwarddonner.com/faq">Q29 on the FAQ page here</a> for the full explanation and alternatives.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up SendGrid
#
#
# Please visit Sendgrid at: https://sendgrid.com/
#
# (Sendgrid is a Twilio company for sending emails.)
#
# __If SendGrid gives you problems, see the alternative implementations on Q29 of my FAQ page at https://edwarddonner.com/faq that includes "Resend Email" in community_contributions/2_lab2_with_resend_email and just skipping email altogether.__
#
# Setting up a SendGrid account is free! (at least, for me, right now).
#
# Once you've created an account, click on:
#
# Settings (left sidebar) >> API Keys >> Create API Key (button on top right)
#
# Copy the key to the clipboard, then add a new line to your .env file:
#
# `SENDGRID_API_KEY=xxxx`
#
# And also, within SendGrid, go to:
#
# Settings (left sidebar) >> Sender Authentication >> "Verify a Single Sender"
# and verify that your own email address is a real email address, so that SendGrid can send emails for you.

# %%
from dotenv import load_dotenv
from agents import Agent, Runner, trace, function_tool
from openai.types.responses import ResponseTextDeltaEvent
from typing import Dict
import sendgrid
import os
from sendgrid.helpers.mail import Mail, Email, To, Content
import asyncio

# %%
load_dotenv(override=True)
# Out:
# True

# %%
# Let's just check emails are working for you

def send_test_email():
    sg = sendgrid.SendGridAPIClient(api_key=os.environ.get('SENDGRID_API_KEY'))
    from_email = Email("nomsterfoods@gmail.com")  # Change to your verified sender
    to_email = To("joeman67@gmail.com")  # Change to your recipient
    content = Content("text/plain", "This is an important test email")
    mail = Mail(from_email, to_email, "Test email", content).get()
    response = sg.client.mail.send.post(request_body=mail)
    print(response.status_code)

send_test_email()
# Out:
# 202

# %% [markdown]
# ### Did you receive the test email
#
# If you get a 202, then you're good to go!
#
# #### Certificate error
#
# If you get an error SSL: CERTIFICATE_VERIFY_FAILED then students Chris S and Oleksandr K have suggestions:
# First run this: `!uv pip install --upgrade certifi`
# Next, run this:
# ```python
# import certifi
# import os
# os.environ['SSL_CERT_FILE'] = certifi.where()
# ```
#
# #### Other errors or no email
#
# If there are other problems, you'll need to check your API key and your verified sender email address in the SendGrid dashboard
#
# Or use the alternative implementation using "Resend Email" in community_contributions/2_lab2_with_resend_email
#
# (Or - you could always replace the email sending code below with a Pushover call, or something to simply write to a flat file)

# %% [markdown]
# ## Step 1: Agent workflow

# %%
instructions1 = "You are a sales agent working for ComplAI, \
a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. \
You write professional, serious cold emails."

instructions2 = "You are a humorous, engaging sales agent working for ComplAI, \
a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. \
You write witty, engaging cold emails that are likely to get a response."

instructions3 = "You are a busy sales agent working for ComplAI, \
a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. \
You write concise, to the point cold emails."

# %%
sales_agent1 = Agent(
        name="Professional Sales Agent",
        instructions=instructions1,
        model="gpt-4o-mini"
)

sales_agent2 = Agent(
        name="Engaging Sales Agent",
        instructions=instructions2,
        model="gpt-4o-mini"
)

sales_agent3 = Agent(
        name="Busy Sales Agent",
        instructions=instructions3,
        model="gpt-4o-mini"
)

# %%
result = Runner.run_streamed(sales_agent1, input="Write a cold sales email")
async for event in result.stream_events():
    if event.type == "raw_response_event" and isinstance(event.data, ResponseTextDeltaEvent):
        print(event.data.delta, end="", flush=True)
# Out:
# Subject: Simplify Your SOC 2 Compliance Journey with ComplAI
#
# Hi [Recipient's Name],
#
# I hope this message finds you well. My name is [Your Name], and I’m reaching out from ComplAI, where we specialize in helping companies like yours navigate the complexities of SOC 2 compliance.
#
# As you know, achieving and maintaining SOC 2 compliance can be a daunting task, especially when managing the myriad of requirements and preparing for audits. Our AI-powered SaaS tool streamlines this process, providing you with automated documentation, risk assessments, and real-time insights into your compliance status.
#
# By leveraging ComplAI, companies have not only reduced compliance preparation time by up to 50%, but they've also improved their audit outcomes significantly.
#
# I would love the opportunity to discuss how ComplAI can support your compliance efforts and simplify your audit process. Would you be available for a brief call next week?
#
# Thank you for your time, and I look forward to connecting.
#
# Best regards,
#
# [Your Name]
# [Your Job Title]
# ComplAI
# [Your Contact Information]
# [Your LinkedIn Profile] (if applicable)

# %%
message = "Write a cold sales email"

with trace("Parallel cold emails"):
    results = await asyncio.gather(
        Runner.run(sales_agent1, message),
        Runner.run(sales_agent2, message),
        Runner.run(sales_agent3, message),
    )

outputs = [result.final_output for result in results]

for output in outputs:
    print(output + "\n\n")
# Out:
# Subject: Streamline Your SOC 2 Compliance Process with AI-Powered Solutions
#
# Hi [Recipient's Name],
#
# I hope this message finds you well. My name is [Your Name], and I’m reaching out from ComplAI, where we specialize in helping organizations like yours navigate the complexities of SOC 2 compliance with ease.
#
# As you may know, achieving and maintaining SOC 2 compliance can be a daunting task, often requiring significant time and resources. Our AI-powered SaaS tool is designed to streamline this process by automating documentation, risk assessments, and audit preparations. This allows your team to focus on what truly matters — growing your business.
#
# Here are a few ways ComplAI can benefit your organization:
#
# - **Automated Workflows**: Simplify your compliance tasks with intelligent automation, reducing the manual effort required.
# - **Real-Time Monitoring**: Stay ahead of compliance requirements with ongoing oversight and insights.
# - **Audit Readiness**: Prepare for audits with ease, ensuring you have all necessary documentation at your fingertips.
#
# We’ve helped numerous companies reduce compliance-related overhead and enhance audit readiness. I would love to explore how we might assist [Recipient's Company] in achieving your compliance goals efficiently.
#
# Could we schedule a quick call next week to discuss your current challenges and how ComplAI can help?
#
# Thank you for your time, and I look forward to your response.
#
# Best regards,
#
# [Your Name]
# [Your Title]
# ComplAI
# [Your Phone Number]
# [Your Email Address]
# [Your Website]
#
#
# Subject: Don't Let SOC2 Compliance Give You the Cold Sweats! ❄️
#
# Hi [Recipient's Name],
#
# Ever feel like getting SOC2 compliant is more daunting than finding a needle in a haystack? Or worse—like trying to assemble IKEA furniture without the instructions? 😅
#
# At ComplAI, we believe compliance shouldn’t feel like a horror movie. Our AI-powered SaaS tool is here to turn your compliance journey into a walk in the park (maybe a brisk jog, but definitely not a marathon!).
#
# ✨ Here’s how we do it:
#
# - **Stress-Free Audits:** With our tool, you’ll have all your documentation organized and ready to go—think of it as your personal compliance assistant that never runs out of coffee (or bad jokes).
#
# - **Real-Time Insights:** Stay ahead of the game! Our AI keeps you updated so you can make decisions faster than your cat can decide to ignore you.
#
# - **Compliance Simplified:** We’ll help you tick all the boxes without losing your sanity. Seriously, your sanity matters!
#
# Would you be open to a quick chat this week? I promise to keep the puns flowing and the compliance talk exciting. 🚀
#
# Looking forward to connecting!
#
# Best,
# [Your Name]
# [Your Position]
# ComplAI
# [Your Phone Number]
# [Your Website]
#
# P.S. If compliance were a dance, we’d be your rhythm coach—let's make you the smoothest dancer in the audit room! 💃
#
#
# Subject: Simplify Your SOC2 Compliance Process
#
# Hi [Recipient's Name],
#
# I hope this message finds you well. I'm reaching out to introduce ComplAI, an AI-powered SaaS tool designed to simplify your SOC2 compliance and audit preparations.
#
# With our platform, you can automate documentation, streamline processes, and reduce the time spent on audits—all while ensuring your compliance standards are met.
#
# Would you be open to a quick call next week to see how ComplAI can help your team save time and minimize compliance headaches?
#
# Best,
# [Your Name]
# [Your Phone Number]
# [Your LinkedIn Profile or Company Website]

# %%
sales_picker = Agent(
    name="sales_picker",
    instructions="You pick the best cold sales email from the given options. \
Imagine you are a customer and pick the one you are most likely to respond to. \
Do not give an explanation; reply with the selected email only.",
    model="gpt-4o-mini"
)

# %%
message = "Write a cold sales email"

with trace("Selection from sales people"):
    results = await asyncio.gather(
        Runner.run(sales_agent1, message),
        Runner.run(sales_agent2, message),
        Runner.run(sales_agent3, message),
    )
    outputs = [result.final_output for result in results]

    emails = "Cold sales emails:\n\n" + "\n\nEmail:\n\n".join(outputs)

    best = await Runner.run(sales_picker, emails)

    print(f"Best sales email:\n{best.final_output}")
# Out:
# Best sales email:
# Subject: Let’s Chat About Making Compliance Less of a “Compliance-ication” 🧐
#
# Hey [First Name],
#
# I hope this email finds you in great spirits and possibly avoiding any accidental head-banging against the compliance wall! 🤦‍♂️
#
# Here at ComplAI, we believe that SOC2 compliance shouldn’t feel like climbing Everest in flip-flops. Wouldn’t it be fantastic if there was a way to breeze through audits while sipping a piña colada? Okay, maybe not *that* easy—but you get my drift!
#
# Our AI-powered tool is like having a compliance guru who never sleeps (or asks for coffee breaks). It helps you navigate the labyrinth of SOC2 compliance with ease, making sure you’re audit-ready and worry-free.
#
# Curious? Let’s schedule a quick chat, and I promise to sprinkle in some humor, some insights, and maybe even a compliance pun or two. (You’ll thank me later!)
#
# Looking forward to connecting!
#
# Cheers,
# [Your Name]
# [Your Position]
# ComplAI
# P.S. “Defeating compliance challenges” can be a breeze—if you have the right tools! 🛠️

# %% [markdown]
# Now go and check out the trace:
#
# https://platform.openai.com/traces

# %% [markdown]
# ## Part 2: use of tools
#
# Now we will add a tool to the mix.
#
# Remember all that json boilerplate and the `handle_tool_calls()` function with the if logic..

# %%
sales_agent1 = Agent(
        name="Professional Sales Agent",
        instructions=instructions1,
        model="gpt-4o-mini",
)

sales_agent2 = Agent(
        name="Engaging Sales Agent",
        instructions=instructions2,
        model="gpt-4o-mini",
)

sales_agent3 = Agent(
        name="Busy Sales Agent",
        instructions=instructions3,
        model="gpt-4o-mini",
)

# %%
sales_agent1
# Out:
# Agent(name='Professional Sales Agent', handoff_description=None, tools=[], mcp_servers=[], mcp_config={}, instructions='You are a sales agent working for ComplAI, a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. You write professional, serious cold emails.', prompt=None, handoffs=[], model='gpt-4o-mini', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice=None, parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, verbosity=None, metadata=None, store=None, include_usage=None, response_include=None, top_logprobs=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True)

# %% [markdown]
# ## Steps 2 and 3: Tools and Agent interactions
#
# Remember all that boilerplate json?
#
# Simply wrap your function with the decorator `@function_tool`

# %%
@function_tool
def send_email(body: str):
    """ Send out an email with the given body to all sales prospects """
    sg = sendgrid.SendGridAPIClient(api_key=os.environ.get('SENDGRID_API_KEY'))
    from_email = Email("nomsterfoods@gmail.com")  # Change to your verified sender
    to_email = To("joeymaza2211@gmail.com")  # Change to your recipient
    content = Content("text/plain", body)
    mail = Mail(from_email, to_email, "Sales email", content).get()
    sg.client.mail.send.post(request_body=mail)
    return {"status": "success"}

# %% [markdown]
# ### This has automatically been converted into a tool, with the boilerplate json created

# %%
# Let's look at it
send_email
# Out:
# FunctionTool(name='send_email', description='Send out an email with the given body to all sales prospects', params_json_schema={'properties': {'body': {'title': 'Body', 'type': 'string'}}, 'required': ['body'], 'title': 'send_email_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001A22954B880>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None)

# %% [markdown]
# ### And you can also convert an Agent into a tool

# %%
tool1 = sales_agent1.as_tool(tool_name="sales_agent1", tool_description="Write a cold sales email")
tool1
# Out:
# FunctionTool(name='sales_agent1', description='Write a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'sales_agent1_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001A2297B9300>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None)

# %% [markdown]
# ### So now we can gather all the tools together:
#
# A tool for each of our 3 email-writing agents
#
# And a tool for our function to send emails

# %%
description = "Write a cold sales email"

tool1 = sales_agent1.as_tool(tool_name="sales_agent1", tool_description=description)
tool2 = sales_agent2.as_tool(tool_name="sales_agent2", tool_description=description)
tool3 = sales_agent3.as_tool(tool_name="sales_agent3", tool_description=description)

tools = [tool1, tool2, tool3, send_email]

tools
# Out:
# [FunctionTool(name='sales_agent1', description='Write a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'sales_agent1_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001A2295B6840>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None),
#  FunctionTool(name='sales_agent2', description='Write a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'sales_agent2_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001A2295B7C40>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None),
#  FunctionTool(name='sales_agent3', description='Write a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'sales_agent3_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001A2269A0680>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None),
#  FunctionTool(name='send_email', description='Send out an email with the given body to all sales prospects', params_json_schema={'properties': {'body': {'title': 'Body', 'type': 'string'}}, 'required': ['body'], 'title': 'send_email_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001A22954B880>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None)]

# %% [markdown]
# ## And now it's time for our Sales Manager - our planning agent

# %%
# Improved instructions thanks to student Guillermo F.

instructions = """
You are a Sales Manager at ComplAI. Your goal is to find the single best cold sales email using the sales_agent tools.
 
Follow these steps carefully:
1. Generate Drafts: Use all three sales_agent tools to generate three different email drafts. Do not proceed until all three drafts are ready.
 
2. Evaluate and Select: Review the drafts and choose the single best email using your judgment of which one is most effective.
 
3. Use the send_email tool to send the best email (and only the best email) to the user.
 
Crucial Rules:
- You must use the sales agent tools to generate the drafts — do not write them yourself.
- You must send ONE email using the send_email tool — never more than one.
"""


sales_manager = Agent(name="Sales Manager", instructions=instructions, tools=tools, model="gpt-4o-mini")

message = "Send a cold sales email addressed to 'Dear CEO'"

with trace("Sales manager"):
    result = await Runner.run(sales_manager, message)

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Wait - you didn't get an email??</h2>
#             <span style="color:#ff7800;">With much thanks to student Chris S. for describing his issue and fixes.
#             If you don't receive an email after running the prior cell, here are some things to check: <br/>
#             First, check your Spam folder! Several students have missed that the emails arrived in Spam!<br/>Second, print(result) and see if you are receiving errors about SSL.
#             If you're receiving SSL errors, then please check out theses <a href="https://chatgpt.com/share/680620ec-3b30-8012-8c26-ca86693d0e3d">networking tips</a> and see the note in the next cell. Also look at the trace in OpenAI, and investigate on the SendGrid website, to hunt for clues. Let me know if I can help!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And one more suggestion to send emails from student Oleksandr on Windows 11:
#
# If you are getting certificate SSL errors, then:
# Run this in a terminal: `uv pip install --upgrade certifi`
#
# Then run this code:
# ```python
# import certifi
# import os
# os.environ['SSL_CERT_FILE'] = certifi.where()
# ```
#
# Thank you Oleksandr!

# %% [markdown]
# ## Remember to check the trace
#
# https://platform.openai.com/traces
#
# And then check your email!!

# %% [markdown]
# ### Handoffs represent a way an agent can delegate to an agent, passing control to it
#
# Handoffs and Agents-as-tools are similar:
#
# In both cases, an Agent can collaborate with another Agent
#
# With tools, control passes back
#
# With handoffs, control passes across

# %%
subject_instructions = "You can write a subject for a cold sales email. \
You are given a message and you need to write a subject for an email that is likely to get a response."

html_instructions = "You can convert a text email body to an HTML email body. \
You are given a text email body which might have some markdown \
and you need to convert it to an HTML email body with simple, clear, compelling layout and design."

subject_writer = Agent(name="Email subject writer", instructions=subject_instructions, model="gpt-4o-mini")
subject_tool = subject_writer.as_tool(tool_name="subject_writer", tool_description="Write a subject for a cold sales email")

html_converter = Agent(name="HTML email body converter", instructions=html_instructions, model="gpt-4o-mini")
html_tool = html_converter.as_tool(tool_name="html_converter",tool_description="Convert a text email body to an HTML email body")

# %%
@function_tool
def send_html_email(subject: str, html_body: str) -> Dict[str, str]:
    """ Send out an email with the given subject and HTML body to all sales prospects """
    sg = sendgrid.SendGridAPIClient(api_key=os.environ.get('SENDGRID_API_KEY'))
    from_email = Email("nomsterfoods@gmail.com")  # Change to your verified sender
    to_email = To("joeymaza2211@gmail.com")  # Change to your recipient
    content = Content("text/html", html_body)
    mail = Mail(from_email, to_email, subject, content).get()
    sg.client.mail.send.post(request_body=mail)
    return {"status": "success"}

# %%
tools = [subject_tool, html_tool, send_html_email]

# %%
tools
# Out:
# [FunctionTool(name='subject_writer', description='Write a subject for a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'subject_writer_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001A2297B9A80>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None),
#  FunctionTool(name='html_converter', description='Convert a text email body to an HTML email body', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'html_converter_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001A2297B8540>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None),
#  FunctionTool(name='send_html_email', description='Send out an email with the given subject and HTML body to all sales prospects', params_json_schema={'properties': {'subject': {'title': 'Subject', 'type': 'string'}, 'html_body': {'title': 'Html Body', 'type': 'string'}}, 'required': ['subject', 'html_body'], 'title': 'send_html_email_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001A229027E20>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None)]

# %%
instructions ="You are an email formatter and sender. You receive the body of an email to be sent. \
You first use the subject_writer tool to write a subject for the email, then use the html_converter tool to convert the body to HTML. \
Finally, you use the send_html_email tool to send the email with the subject and HTML body."


emailer_agent = Agent(
    name="Email Manager",
    instructions=instructions,
    tools=tools,
    model="gpt-4o-mini",
    handoff_description="Convert an email to HTML and send it")

# %% [markdown]
# ### Now we have 3 tools and 1 handoff

# %%
tools = [tool1, tool2, tool3]
handoffs = [emailer_agent]
print(tools)
print(handoffs)
# Out:
# [FunctionTool(name='sales_agent1', description='Write a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'sales_agent1_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001A2295B6840>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='sales_agent2', description='Write a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'sales_agent2_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001A2295B7C40>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='sales_agent3', description='Write a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'sales_agent3_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001A2269A0680>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None)]
# [Agent(name='Email Manager', handoff_description='Convert an email to HTML and send it', tools=[FunctionTool(name='subject_writer', description='Write a subject for a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'subject_writer_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001A2297B9A80>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='html_converter', description='Convert a text email body to an HTML email body', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'html_converter_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001A2297B8540>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='send_html_email', description='Send out an email with the given subject and HTML body to all sales prospects', params_json_schema={'properties': {'subject': {'title': 'Subject', 'type': 'string'}, 'html_body': {'title': 'Html Body', 'type': 'string'}}, 'required': ['subject', 'html_body'], 'title': 'send_html_email_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001A229027E20>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None)], mcp_servers=[], mcp_config={}, instructions='You are an email formatter and sender. You receive the body of an email to be sent. You first use the subject_writer tool to write a subject for the email, then use the html_converter tool to convert the body to HTML. Finally, you use the send_html_email tool to send the email with the subject and HTML body.', prompt=None, handoffs=[], model='gpt-4o-mini', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice=None, parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, verbosity=None, metadata=None, store=None, include_usage=None, response_include=None, top_logprobs=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True)]

# %%
# Improved instructions thanks to student Guillermo F.

sales_manager_instructions = """
You are a Sales Manager at ComplAI. Your goal is to find the single best cold sales email using the sales_agent tools.
 
Follow these steps carefully:
1. Generate Drafts: Use all three sales_agent tools to generate three different email drafts. Do not proceed until all three drafts are ready.
 
2. Evaluate and Select: Review the drafts and choose the single best email using your judgment of which one is most effective.
You can use the tools multiple times if you're not satisfied with the results from the first try.
 
3. Handoff for Sending: Pass ONLY the winning email draft to the 'Email Manager' agent. The Email Manager will take care of formatting and sending.
 
Crucial Rules:
- You must use the sales agent tools to generate the drafts — do not write them yourself.
- You must hand off exactly ONE email to the Email Manager — never more than one.
"""


sales_manager = Agent(
    name="Sales Manager",
    instructions=sales_manager_instructions,
    tools=tools,
    handoffs=handoffs,
    model="gpt-4o-mini")

message = "Send out a cold sales email addressed to Dear CEO from Alice"

with trace("Automated SDR"):
    result = await Runner.run(sales_manager, message)
# Out:
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[28], line 30
#      27 message = "Send out a cold sales email addressed to Dear CEO from Alice"
#      29 with trace("Automated SDR"):
# ---> 30     result = await Runner.run(sales_manager, message)
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\agents\run.py:296, in Runner.run(cls, starting_agent, input, context, max_turns, hooks, run_config, previous_response_id, conversation_id, session)
#     247 """
#     248 Run a workflow starting at the given agent.
#     249
#    (...)    292     type of the output.
#     293 """
#     295 runner = DEFAULT_AGENT_RUNNER
# --> 296 return await runner.run(
#     297     starting_agent,
#     298     input,
#     299     context=context,
#     300     max_turns=max_turns,
#     301     hooks=hooks,
#     302     run_config=run_config,
#     303     previous_response_id=previous_response_id,
#     304     conversation_id=conversation_id,
#     305     session=session,
#     306 )
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\agents\run.py:571, in AgentRunner.run(self, starting_agent, input, **kwargs)
#     548     input_guardrail_results, turn_result = await asyncio.gather(
#     549         self._run_input_guardrails(
#     550             starting_agent,
#    (...)    568         ),
#     569     )
#     570 else:
# --> 571     turn_result = await self._run_single_turn(
#     572         agent=current_agent,
#     573         all_tools=all_tools,
#     574         original_input=original_input,
#     575         generated_items=generated_items,
#     576         hooks=hooks,
#     577         context_wrapper=context_wrapper,
#     578         run_config=run_config,
#     579         should_run_agent_start_hooks=should_run_agent_start_hooks,
#     580         tool_use_tracker=tool_use_tracker,
#     581         previous_response_id=previous_response_id,
#     582         conversation_id=conversation_id,
#     583     )
#     584 should_run_agent_start_hooks = False
#     586 model_responses.append(turn_result.model_response)
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\agents\run.py:1262, in AgentRunner._run_single_turn(cls, agent, all_tools, original_input, generated_items, hooks, context_wrapper, run_config, should_run_agent_start_hooks, tool_use_tracker, previous_response_id, conversation_id)
#    1244 input.extend([generated_item.to_input_item() for generated_item in generated_items])
#    1246 new_response = await cls._get_new_response(
#    1247     agent,
#    1248     system_prompt,
#    (...)   1259     prompt_config,
#    1260 )
# -> 1262 return await cls._get_single_step_result_from_response(
#    1263     agent=agent,
#    1264     original_input=original_input,
#    1265     pre_step_items=generated_items,
#    1266     new_response=new_response,
#    1267     output_schema=output_schema,
#    1268     all_tools=all_tools,
#    1269     handoffs=handoffs,
#    1270     hooks=hooks,
#    1271     context_wrapper=context_wrapper,
#    1272     run_config=run_config,
#    1273     tool_use_tracker=tool_use_tracker,
#    1274 )
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\agents\run.py:1311, in AgentRunner._get_single_step_result_from_response(cls, agent, all_tools, original_input, pre_step_items, new_response, output_schema, handoffs, hooks, context_wrapper, run_config, tool_use_tracker, event_queue)
#    1308     if handoff_items:
#    1309         RunImpl.stream_step_items_to_queue(cast(list[RunItem], handoff_items), event_queue)
# -> 1311 return await RunImpl.execute_tools_and_side_effects(
#    1312     agent=agent,
#    1313     original_input=original_input,
#    1314     pre_step_items=pre_step_items,
#    1315     new_response=new_response,
#    1316     processed_response=processed_response,
#    1317     output_schema=output_schema,
#    1318     hooks=hooks,
#    1319     context_wrapper=context_wrapper,
#    1320     run_config=run_config,
#    1321 )
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\agents\_run_impl.py:274, in RunImpl.execute_tools_and_side_effects(cls, agent, original_input, pre_step_items, new_response, processed_response, output_schema, hooks, context_wrapper, run_config)
#     268 new_step_items.extend(processed_response.new_items)
#     270 # First, lets run the tool calls - function tools and computer actions
#     271 (
#     272     (function_results, tool_input_guardrail_results, tool_output_guardrail_results),
#     273     computer_results,
# --> 274 ) = await asyncio.gather(
#     275     cls.execute_function_tool_calls(
#     276         agent=agent,
#     277         tool_runs=processed_response.functions,
#     278         hooks=hooks,
#     279         context_wrapper=context_wrapper,
#     280         config=run_config,
#     281     ),
#     282     cls.execute_computer_actions(
#     283         agent=agent,
#     284         actions=processed_response.computer_actions,
#     285         hooks=hooks,
#     286         context_wrapper=context_wrapper,
#     287         config=run_config,
#     288     ),
#     289 )
#     290 new_step_items.extend([result.run_item for result in function_results])
#     291 new_step_items.extend(computer_results)
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\agents\_run_impl.py:818, in RunImpl.execute_function_tool_calls(cls, agent, tool_runs, hooks, context_wrapper, config)
#     815     function_tool = tool_run.function_tool
#     816     tasks.append(run_single_tool(function_tool, tool_run.tool_call))
# --> 818 results = await asyncio.gather(*tasks)
#     820 function_tool_results = [
#     821     FunctionToolResult(
#     822         tool=tool_run.function_tool,
#    (...)    830     for tool_run, result in zip(tool_runs, results)
#     831 ]
#     833 return function_tool_results, tool_input_guardrail_results, tool_output_guardrail_results
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\agents\_run_impl.py:769, in RunImpl.execute_function_tool_calls.<locals>.run_single_tool(func_tool, tool_call)
#     766     final_result = rejected_message
#     767 else:
#     768     # 2) Actually run the tool
# --> 769     real_result = await cls._execute_tool_with_hooks(
#     770         func_tool=func_tool,
#     771         tool_context=tool_context,
#     772         agent=agent,
#     773         hooks=hooks,
#     774         tool_call=tool_call,
#     775     )
#     777     # 3) Run output tool guardrails, if any
#     778     final_result = await cls._execute_output_guardrails(
#     779         func_tool=func_tool,
#     780         tool_context=tool_context,
#    (...)    783         tool_output_guardrail_results=tool_output_guardrail_results,
#     784     )
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\agents\_run_impl.py:726, in RunImpl._execute_tool_with_hooks(cls, func_tool, tool_context, agent, hooks, tool_call)
#     705 """Execute the core tool function with before/after hooks.
#     706
#     707 Args:
#    (...)    715     The result from the tool execution.
#     716 """
#     717 await asyncio.gather(
#     718     hooks.on_tool_start(tool_context, agent, func_tool),
#     719     (
#    (...)    723     ),
#     724 )
# --> 726 return await func_tool.on_invoke_tool(tool_context, tool_call.arguments)
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\agents\tool.py:449, in function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool(ctx, input)
#     447 async def _on_invoke_tool(ctx: ToolContext[Any], input: str) -> Any:
#     448     try:
# --> 449         return await _on_invoke_tool_impl(ctx, input)
#     450     except Exception as e:
#     451         if failure_error_function is None:
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\agents\tool.py:431, in function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool_impl(ctx, input)
#     429 if inspect.iscoroutinefunction(the_func):
#     430     if schema.takes_context:
# --> 431         result = await the_func(ctx, *args, **kwargs_dict)
#     432     else:
#     433         result = await the_func(*args, **kwargs_dict)
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\agents\agent.py:425, in Agent.as_tool.<locals>.run_agent(context, input)
#     421 from .run import DEFAULT_MAX_TURNS, Runner
#     423 resolved_max_turns = max_turns if max_turns is not None else DEFAULT_MAX_TURNS
# --> 425 output = await Runner.run(
#     426     starting_agent=self,
#     427     input=input,
#     428     context=context.context,
#     429     run_config=run_config,
#     430     max_turns=resolved_max_turns,
#     431     hooks=hooks,
#     432     previous_response_id=previous_response_id,
#     433     conversation_id=conversation_id,
#     434     session=session,
#     435 )
#     436 if custom_output_extractor:
#     437     return await custom_output_extractor(output)
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\agents\run.py:296, in Runner.run(cls, starting_agent, input, context, max_turns, hooks, run_config, previous_response_id, conversation_id, session)
#     247 """
#     248 Run a workflow starting at the given agent.
#     249
#    (...)    292     type of the output.
#     293 """
#     295 runner = DEFAULT_AGENT_RUNNER
# --> 296 return await runner.run(
#     297     starting_agent,
#     298     input,
#     299     context=context,
#     300     max_turns=max_turns,
#     301     hooks=hooks,
#     302     run_config=run_config,
#     303     previous_response_id=previous_response_id,
#     304     conversation_id=conversation_id,
#     305     session=session,
#     306 )
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\agents\run.py:548, in AgentRunner.run(self, starting_agent, input, **kwargs)
#     543 logger.debug(
#     544     f"Running agent {current_agent.name} (turn {current_turn})",
#     545 )
#     547 if current_turn == 1:
# --> 548     input_guardrail_results, turn_result = await asyncio.gather(
#     549         self._run_input_guardrails(
#     550             starting_agent,
#     551             starting_agent.input_guardrails
#     552             + (run_config.input_guardrails or []),
#     553             _copy_str_or_list(prepared_input),
#     554             context_wrapper,
#     555         ),
#     556         self._run_single_turn(
#     557             agent=current_agent,
#     558             all_tools=all_tools,
#     559             original_input=original_input,
#     560             generated_items=generated_items,
#     561             hooks=hooks,
#     562             context_wrapper=context_wrapper,
#     563             run_config=run_config,
#     564             should_run_agent_start_hooks=should_run_agent_start_hooks,
#     565             tool_use_tracker=tool_use_tracker,
#     566             previous_response_id=previous_response_id,
#     567             conversation_id=conversation_id,
#     568         ),
#     569     )
#     570 else:
#     571     turn_result = await self._run_single_turn(
#     572         agent=current_agent,
#     573         all_tools=all_tools,
#    (...)    582         conversation_id=conversation_id,
#     583     )
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\agents\run.py:1246, in AgentRunner._run_single_turn(cls, agent, all_tools, original_input, generated_items, hooks, context_wrapper, run_config, should_run_agent_start_hooks, tool_use_tracker, previous_response_id, conversation_id)
#    1243 input = ItemHelpers.input_to_new_input_list(original_input)
#    1244 input.extend([generated_item.to_input_item() for generated_item in generated_items])
# -> 1246 new_response = await cls._get_new_response(
#    1247     agent,
#    1248     system_prompt,
#    1249     input,
#    1250     output_schema,
#    1251     all_tools,
#    1252     handoffs,
#    1253     hooks,
#    1254     context_wrapper,
#    1255     run_config,
#    1256     tool_use_tracker,
#    1257     previous_response_id,
#    1258     conversation_id,
#    1259     prompt_config,
#    1260 )
#    1262 return await cls._get_single_step_result_from_response(
#    1263     agent=agent,
#    1264     original_input=original_input,
#    (...)   1273     tool_use_tracker=tool_use_tracker,
#    1274 )
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\agents\run.py:1494, in AgentRunner._get_new_response(cls, agent, system_prompt, input, output_schema, all_tools, handoffs, hooks, context_wrapper, run_config, tool_use_tracker, previous_response_id, conversation_id, prompt_config)
#    1479 # If we have run hooks, or if the agent has hooks, we need to call them before the LLM call
#    1480 await asyncio.gather(
#    1481     hooks.on_llm_start(context_wrapper, agent, filtered.instructions, filtered.input),
#    1482     (
#    (...)   1491     ),
#    1492 )
# -> 1494 new_response = await model.get_response(
#    1495     system_instructions=filtered.instructions,
#    1496     input=filtered.input,
#    1497     model_settings=model_settings,
#    1498     tools=all_tools,
#    1499     output_schema=output_schema,
#    1500     handoffs=handoffs,
#    1501     tracing=get_model_tracing_impl(
#    1502         run_config.tracing_disabled, run_config.trace_include_sensitive_data
#    1503     ),
#    1504     previous_response_id=previous_response_id,
#    1505     conversation_id=conversation_id,
#    1506     prompt=prompt_config,
#    1507 )
#    1509 context_wrapper.usage.add(new_response.usage)
#    1511 # If we have run hooks, or if the agent has hooks, we need to call them after the LLM call
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\agents\models\openai_responses.py:90, in OpenAIResponsesModel.get_response(self, system_instructions, input, model_settings, tools, output_schema, handoffs, tracing, previous_response_id, conversation_id, prompt)
#      88 with response_span(disabled=tracing.is_disabled()) as span_response:
#      89     try:
# ---> 90         response = await self._fetch_response(
#      91             system_instructions,
#      92             input,
#      93             model_settings,
#      94             tools,
#      95             output_schema,
#      96             handoffs,
#      97             previous_response_id=previous_response_id,
#      98             conversation_id=conversation_id,
#      99             stream=False,
#     100             prompt=prompt,
#     101         )
#     103         if _debug.DONT_LOG_MODEL_DATA:
#     104             logger.debug("LLM responded")
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\agents\models\openai_responses.py:305, in OpenAIResponsesModel._fetch_response(self, system_instructions, input, model_settings, tools, output_schema, handoffs, previous_response_id, conversation_id, stream, prompt)
#     302     else:
#     303         response_format = {"verbosity": model_settings.verbosity}
# --> 305 return await self._client.responses.create(
#     306     previous_response_id=self._non_null_or_not_given(previous_response_id),
#     307     conversation=self._non_null_or_not_given(conversation_id),
#     308     instructions=self._non_null_or_not_given(system_instructions),
#     309     model=self.model,
#     310     input=list_input,
#     311     include=include,
#     312     tools=converted_tools_payload,
#     313     prompt=self._non_null_or_not_given(prompt),
#     314     temperature=self._non_null_or_not_given(model_settings.temperature),
#     315     top_p=self._non_null_or_not_given(model_settings.top_p),
#     316     truncation=self._non_null_or_not_given(model_settings.truncation),
#     317     max_output_tokens=self._non_null_or_not_given(model_settings.max_tokens),
#     318     tool_choice=tool_choice,
#     319     parallel_tool_calls=parallel_tool_calls,
#     320     stream=stream,
#     321     extra_headers=self._merge_headers(model_settings),
#     322     extra_query=model_settings.extra_query,
#     323     extra_body=model_settings.extra_body,
#     324     text=response_format,
#     325     store=self._non_null_or_not_given(model_settings.store),
#     326     reasoning=self._non_null_or_not_given(model_settings.reasoning),
#     327     metadata=self._non_null_or_not_given(model_settings.metadata),
#     328     **extra_args,
#     329 )
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\openai\resources\responses\responses.py:2259, in AsyncResponses.create(self, background, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#    2222 async def create(
#    2223     self,
#    2224     *,
#    (...)   2257     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    2258 ) -> Response | AsyncStream[ResponseStreamEvent]:
# -> 2259     return await self._post(
#    2260         "/responses",
#    2261         body=await async_maybe_transform(
#    2262             {
#    2263                 "background": background,
#    2264                 "conversation": conversation,
#    2265                 "include": include,
#    2266                 "input": input,
#    2267                 "instructions": instructions,
#    2268                 "max_output_tokens": max_output_tokens,
#    2269                 "max_tool_calls": max_tool_calls,
#    2270                 "metadata": metadata,
#    2271                 "model": model,
#    2272                 "parallel_tool_calls": parallel_tool_calls,
#    2273                 "previous_response_id": previous_response_id,
#    2274                 "prompt": prompt,
#    2275                 "prompt_cache_key": prompt_cache_key,
#    2276                 "reasoning": reasoning,
#    2277                 "safety_identifier": safety_identifier,
#    2278                 "service_tier": service_tier,
#    2279                 "store": store,
#    2280                 "stream": stream,
#    2281                 "stream_options": stream_options,
#    2282                 "temperature": temperature,
#    2283                 "text": text,
#    2284                 "tool_choice": tool_choice,
#    2285                 "tools": tools,
#    2286                 "top_logprobs": top_logprobs,
#    2287                 "top_p": top_p,
#    2288                 "truncation": truncation,
#    2289                 "user": user,
#    2290             },
#    2291             response_create_params.ResponseCreateParamsStreaming
#    2292             if stream
#    2293             else response_create_params.ResponseCreateParamsNonStreaming,
#    2294         ),
#    2295         options=make_request_options(
#    2296             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    2297         ),
#    2298         cast_to=Response,
#    2299         stream=stream or False,
#    2300         stream_cls=AsyncStream[ResponseStreamEvent],
#    2301     )
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\openai\_base_client.py:1794, in AsyncAPIClient.post(self, path, cast_to, body, files, options, stream, stream_cls)
#    1780 async def post(
#    1781     self,
#    1782     path: str,
#    (...)   1789     stream_cls: type[_AsyncStreamT] | None = None,
#    1790 ) -> ResponseT | _AsyncStreamT:
#    1791     opts = FinalRequestOptions.construct(
#    1792         method="post", url=path, json_data=body, files=await async_to_httpx_files(files), **options
#    1793     )
# -> 1794     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\openai\_base_client.py:1529, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1527 response = None
#    1528 try:
# -> 1529     response = await self._client.send(
#    1530         request,
#    1531         stream=stream or self._should_stream_response_body(request=request),
#    1532         **kwargs,
#    1533     )
#    1534 except httpx.TimeoutException as err:
#    1535     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\httpx\_client.py:1629, in AsyncClient.send(self, request, stream, auth, follow_redirects)
#    1625 self._set_timeout(request)
#    1627 auth = self._build_request_auth(request, auth)
# -> 1629 response = await self._send_handling_auth(
#    1630     request,
#    1631     auth=auth,
#    1632     follow_redirects=follow_redirects,
#    1633     history=[],
#    1634 )
#    1635 try:
#    1636     if not stream:
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\httpx\_client.py:1657, in AsyncClient._send_handling_auth(self, request, auth, follow_redirects, history)
#    1654 request = await auth_flow.__anext__()
#    1656 while True:
# -> 1657     response = await self._send_handling_redirects(
#    1658         request,
#    1659         follow_redirects=follow_redirects,
#    1660         history=history,
#    1661     )
#    1662     try:
#    1663         try:
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\httpx\_client.py:1694, in AsyncClient._send_handling_redirects(self, request, follow_redirects, history)
#    1691 for hook in self._event_hooks["request"]:
#    1692     await hook(request)
# -> 1694 response = await self._send_single_request(request)
#    1695 try:
#    1696     for hook in self._event_hooks["response"]:
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\httpx\_client.py:1730, in AsyncClient._send_single_request(self, request)
#    1725     raise RuntimeError(
#    1726         "Attempted to send an sync request with an AsyncClient instance."
#    1727     )
#    1729 with request_context(request=request):
# -> 1730     response = await transport.handle_async_request(request)
#    1732 assert isinstance(response.stream, AsyncByteStream)
#    1733 response.request = request
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\httpx\_transports\default.py:394, in AsyncHTTPTransport.handle_async_request(self, request)
#     381 req = httpcore.Request(
#     382     method=request.method,
#     383     url=httpcore.URL(
#    (...)    391     extensions=request.extensions,
#     392 )
#     393 with map_httpcore_exceptions():
# --> 394     resp = await self._pool.handle_async_request(req)
#     396 assert isinstance(resp.stream, typing.AsyncIterable)
#     398 return Response(
#     399     status_code=resp.status,
#     400     headers=resp.headers,
#     401     stream=AsyncResponseStream(resp.stream),
#     402     extensions=resp.extensions,
#     403 )
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\httpcore\_async\connection_pool.py:256, in AsyncConnectionPool.handle_async_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     await self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.AsyncIterable)
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\httpcore\_async\connection_pool.py:236, in AsyncConnectionPool.handle_async_request(self, request)
#     232 connection = await pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = await connection.handle_async_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\httpcore\_async\connection.py:103, in AsyncHTTPConnection.handle_async_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return await self._connection.handle_async_request(request)
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\httpcore\_async\http11.py:136, in AsyncHTTP11Connection.handle_async_request(self, request)
#     134     async with Trace("response_closed", logger, request) as trace:
#     135         await self._response_closed()
# --> 136 raise exc
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\httpcore\_async\http11.py:106, in AsyncHTTP11Connection.handle_async_request(self, request)
#      95     pass
#      97 async with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = await self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\httpcore\_async\http11.py:177, in AsyncHTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = await self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\httpcore\_async\http11.py:217, in AsyncHTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = await self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\httpcore\_backends\anyio.py:35, in AnyIOStream.read(self, max_bytes, timeout)
#      33 with anyio.fail_after(timeout):
#      34     try:
# ---> 35         return await self._stream.receive(max_bytes=max_bytes)
#      36     except anyio.EndOfStream:  # pragma: nocover
#      37         return b""
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\anyio\streams\tls.py:237, in TLSStream.receive(self, max_bytes)
#     236 async def receive(self, max_bytes: int = 65536) -> bytes:
# --> 237     data = await self._call_sslobject_method(self._ssl_object.read, max_bytes)
#     238     if not data:
#     239         raise EndOfStream
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\anyio\streams\tls.py:180, in TLSStream._call_sslobject_method(self, func, *args)
#     177     if self._write_bio.pending:
#     178         await self.transport_stream.send(self._write_bio.read())
# --> 180     data = await self.transport_stream.receive()
#     181 except EndOfStream:
#     182     self._read_bio.write_eof()
#
# File c:\Users\joema\ai_projects\ai_engineering\agents\.venv\Lib\site-packages\anyio\_backends\_asyncio.py:1263, in SocketStream.receive(self, max_bytes)
#    1257 if (
#    1258     not self._protocol.read_event.is_set()
#    1259     and not self._transport.is_closing()
#    1260     and not self._protocol.is_at_eof
#    1261 ):
#    1262     self._transport.resume_reading()
# -> 1263     await self._protocol.read_event.wait()
#    1264     self._transport.pause_reading()
#    1265 else:
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.12-windows-x86_64-none\Lib\asyncio\locks.py:212, in Event.wait(self)
#     210 self._waiters.append(fut)
#     211 try:
# --> 212     await fut
#     213     return True
#     214 finally:
#
# CancelledError:

# %% [markdown]
# ### Remember to check the trace
#
# https://platform.openai.com/traces
#
# And then check your email!!

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Can you identify the Agentic design patterns that were used here?<br/>
#             What is the 1 line that changed this from being an Agentic "workflow" to "agent" under Anthropic's definition?<br/>
#             Try adding in more tools and Agents! You could have tools that handle the mail merge to send to a list.<br/><br/>
#             HARD CHALLENGE: research how you can have SendGrid call a Callback webhook when a user replies to an email,
#             Then have the SDR respond to keep the conversation going! This may require some "vibe coding" 😂
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">This is immediately applicable to Sales Automation; but more generally this could be applied to  end-to-end automation of any business process through conversations and tools. Think of ways you could apply an Agent solution
#             like this in your day job.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Extra note:
#
# Google has released their Agent Development Kit (ADK). It's not yet got the traction of the other frameworks on this course, but it's getting some attention. It's interesting to note that it looks quite similar to OpenAI Agents SDK. To give you a preview, here's a peak at sample code from ADK:
#
# ```
# root_agent = Agent(
#     name="weather_time_agent",
#     model="gemini-2.0-flash",
#     description="Agent to answer questions about the time and weather in a city.",
#     instruction="You are a helpful agent who can answer user questions about the time and weather in a city.",
#     tools=[get_weather, get_current_time]
# )
# ```
#
# Well, that looks familiar!
#
# And a student has contributed a customer care agent in community_contributions that uses ADK.
